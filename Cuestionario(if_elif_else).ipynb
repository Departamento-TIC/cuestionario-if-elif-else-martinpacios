# %% [markdown]
# <a href="https://colab.research.google.com/github/Departamento-TIC/cuestionario-if-elif-else-martinpacios/blob/main/Cuestionario(if_elif_else).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 3: Créate un Cuestionario [Programar Juegos Arcade con Python y Pygame](http://programarcadegames.com/index.php)
#
#
# #Descripción
# Estas son las características que debe tener tu cuestionario:
#
#
# 1.   Créalo con cinco o más preguntas. Puedes preguntar cosas que requieran
# *   un número como respuesta (por ejemplo; ¿Cuánto es 1+1?)
# *   texto (Por ejemplo; ¿Cuál es el apellido de Harry Potter?)
# *   una selección (¿Cuál de estas opciones son las correctas A, B, o C?)
#
# 2.   Si permites que el usuario introduzca respuestas no numéricas, piensa y cubre las distintas formas en que podría contestar. Por ejemplo, si la respuesta es “a”, sería aceptable también “A”? Échale un vistazo a la Sección 3.6 para que recuerdes cómo conseguir esto.
#
# 3. Debes permitir que el usuario sepa que ha acertado con la respuesta correcta. Imprime un mensaje basado en esa respuesta.
# 4. Debes llevar la cuenta del número de respuestas acertadas.
# 5. Al final del programa, deberás mostrar el porcentaje de respuestas contestadas correctamente por el usuario.
#
# #Ejemplo de ejecución
#
# ```
# ¡A jugar!
#
# ¿De cuántos libros consta la serie de Harry Potter? 7
# Correcto!
#
# ¿Cuánto es 3*(2-1)? 3
# Correcto!
#
# ¿Cuánto es 3*2-1? 5
# Correcto!
#
# ¿Quién canta Black Horse and the Cherry Tree?
# 1. Kelly Clarkson
# 2. K.T. Tunstall
# 3. Hillary Duff
# 4. Bon Jovi
# ? 2
# Correcto!
#
# ¿Qué personaje aparece en el billete de un dólar?
# 1. George Washington
# 2. Abraham Lincoln
# 3. John Adams
# 4. Thomas Jefferson
# ? 2
# No.
#
# Mis felicitaciones, has conseguido 4 respuestas correctas!
# Eso es una puntuación del 80 por ciento.
# ```

# %% [markdown]
# # Crea un celda de código debajo y escribe allí tu programa

# %%
print ("¡A jugar!,a jugar")

contador = 0
total_preguntas = 5

pregunta_1 = int(input("¿Cuánto es 5+2? "))
if pregunta_1 == 7:
  print ("Correcto!")
  contador += 1
else:
  print ("Incorrecto.")

pregunta_2 = int(input("¿De cuántos libros consta la serie de Harry Potter? "))
if pregunta_2 == 7:
  print ("Correcto!")
  contador += 1
else:
  print ("Incorrecto.")

pregunta_3 = int(input("¿Cuánto es 4+2*8? "))
if pregunta_3 ==  20:
  print ("Correcto!")
  contador += 1
else:
  print ("Incorrecto.")

pregunta_4 = int(input("""
¿Qué personaje aparece en el billete de un dólar?
1. George Washington
2. Abraham Lincoln
3. John Adams
4. Thomas Jefferson
? """))
if pregunta_4 ==  2:
 print ("Correcto!")
 contador += 1
else:
  print ("Incorrecto.")

pregunta_5 = input("¿Cuál es el planeta más cercano al sol? ")
if pregunta_5.lower() == "mercurio":
  print ("Correcto!")
  contador += 1
elif pregunta_5 == "Mercurio":
  print ("Correcto!")
  contador += 1
else:
  print ("Incorrecto.")

print(f"\n¡Mis felicitaciones, has conseguido {contador} respuestas correctas!")
if total_preguntas > 0:
    porcentaje = (contador / total_preguntas) * 100
    print(f"Eso es una puntuación del {porcentaje:.0f} por ciento.")
else:
    print("No hay preguntas para calcular el porcentaje.")
# Out:
# ¡A jugar!
# ¿Cuánto es 5+2? 6
# Incorrecto.
# ¿De cuántos libros consta la serie de Harry Potter? 7
# Correcto!
# ¿Cuánto es 4+2*8? 20
# Correcto!
#
# ¿Qué personaje aparece en el billete de un dólar?
# 1. George Washington
# 2. Abraham Lincoln
# 3. John Adams
# 4. Thomas Jefferson
# ? 1
# Incorrecto.
# ¿Cuál es el planeta más cercano al sol? Mercurio
# Correcto!
#
# ¡Mis felicitaciones, has conseguido 3 respuestas correctas!
# Eso es una puntuación del 60 por ciento.
